# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#control display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid",rc={"axes.facecolor":"#CAF1DE"})

# %%
df = pd.read_csv('bse_dataset.csv')
df
# Out:
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
#Data analysis workflow
#understanding of dataset preparation
#data cleaning - data cleaning, wrong data, wrong format null values, duplicate values

# %%
#understanding of data struture
#checking shape of data struture
#checking shape of data - understanding rows
df.shape
# Out:
# (97, 11)

# %%
#checking column names
df.columns
# Out:
# Index(['Timestamp', 'What is your gender?', 'Age', 'What is your emotion?',
#        'Year of birth', 'What is your CGPA?',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? '],
#       dtype='object')

# %%
#check null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
# ...

# %%
#loading data set2
df2 = pd.read_csv('bse_dataset2.csv')
df2
# Out:
#         Timestamp What is your gender?  Age What is your emotion?  \
# 0   5/7/2023 9:38                 Male   21               Content
# 1   5/7/2023 9:38        Marabou stock   45                 Weird
# 2   5/7/2023 9:39              Female    20                 Happy
# 3   5/7/2023 9:39                 Male   21                 Happy
# 4   5/7/2023 9:39               Female   21                 Happy
# ..            ...                  ...  ...                   ...
# 92  5/7/2023 9:53              Female    68                   Sad
# 93  5/7/2023 9:54                 Male   29               Hopeful
# 94  5/7/2023 9:54                 Male   22      Fighting poverty
# 95  5/7/2023 9:54                 Male   23          good and bad
# 96  5/7/2023 9:54                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# 0           2002               4.22                                      No
# ...

# %%
#check null values
df2.isnull().sum().sort_values(ascending=False)
# Out:
# What is your emotion?                                 2
# Year of birth                                         1
# What is your CGPA?                                    1
# Do you have Anxiety?                                  1
# Did you have seek any specialist for a treatment?     1
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Panic attack?                             0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 97 non-null     int64
#  3   What is your emotion?                               95 non-null     object
#  4   Year of birth                                       96 non-null     object
#  5   What is your CGPA?                                  96 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %%
df2.dtypes
# Out:
# Timestamp                                             object
# What is your gender?                                  object
# Age                                                    int64
# What is your emotion?                                 object
# Year of birth                                         object
# What is your CGPA?                                    object
# Do you have a Girl Friend or BOY Friend               object
# Do you have Depression?                               object
# Do you have Anxiety?                                  object
# Do you have Panic attack?                             object
# Did you have seek any specialist for a treatment?     object
# dtype: object

# %%
#check null values in percentage
for i in df2.columns:
    if df2[i].isnull().any():
        print(i, "-----", df2[i].isnull().sum()*100/df2.shape[0],"%")
# Out:
# What is your emotion? ----- 2.0618556701030926 %
# Year of birth ----- 1.0309278350515463 %
# What is your CGPA? ----- 1.0309278350515463 %
# Do you have Anxiety? ----- 1.0309278350515463 %
# Did you have seek any specialist for a treatment?  ----- 1.0309278350515463 %

# %%
#check null values in figure
import missingno as msno
msno.bar(df2, color= "grey",fontsize=24);

# %%
#checking for duplicate
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe()
# Out:
#              Age
# count  97.000000
# mean   22.917526
# std     6.277722
# min    19.000000
# 25%    21.000000
# 50%    21.000000
# 75%    22.000000
# max    68.000000

# %%
df2.describe().T
# Out:
#      count       mean       std   min   25%   50%   75%   max
# Age   97.0  22.917526  6.277722  19.0  21.0  21.0  22.0  68.0

# %%
df2.describe(include="object").T
# Out:
#                                                    count unique  \
# Timestamp                                             97     13
# What is your gender?                                  97     10
# What is your emotion?                                 95     49
# Year of birth                                         96     18
# What is your CGPA?                                    96     60
# Do you have a Girl Friend or BOY Friend               97     14
# Do you have Depression?                               97     13
# Do you have Anxiety?                                  96     17
# Do you have Panic attack?                             97     13
# Did you have seek any specialist for a treatment?     96      9
#
#                                                               top freq
# Timestamp                                           5/7/2023 9:40   23
# What is your gender?                                         Male   41
# ...

# %%
#check unique values
for i in df2.columns:
    print(i, "----", df2[i].unique(), "****",df2[i].unique())
# Out:
# Timestamp ---- ['5/7/2023 9:38' '5/7/2023 9:39' '5/7/2023 9:40' '5/7/2023 9:41'
#  '5/7/2023 9:42' '5/7/2023 9:43' '5/7/2023 9:44' '5/7/2023 9:45'
#  '5/7/2023 9:49' '5/7/2023 9:51' '5/7/2023 9:52' '5/7/2023 9:53'
#  '5/7/2023 9:54'] **** ['5/7/2023 9:38' '5/7/2023 9:39' '5/7/2023 9:40' '5/7/2023 9:41'
#  '5/7/2023 9:42' '5/7/2023 9:43' '5/7/2023 9:44' '5/7/2023 9:45'
#  '5/7/2023 9:49' '5/7/2023 9:51' '5/7/2023 9:52' '5/7/2023 9:53'
#  '5/7/2023 9:54']
# What is your gender? ---- ['Male' 'Marabou stock' 'Female ' 'Female' 'female' 'MALE' 'FEMALE' 'male'
#  'Yes' 'M'] **** ['Male' 'Marabou stock' 'Female ' 'Female' 'female' 'MALE' 'FEMALE' 'male'
#  'Yes' 'M']
# Age ---- [21 45 20 23 22 24 25 28 19 50 30 68 29] **** [21 45 20 23 22 24 25 28 19 50 30 68 29]
# What is your emotion? ---- ['Content' 'Weird' 'Happy' 'Happy ' 'irritated ' 'In a state of wonder'
#  'Sad' 'happy' 'Moody' 'fine' 'TIRED FOR NOW' 'Jolly' 'Frustrated'
# ...
