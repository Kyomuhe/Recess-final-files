# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#control display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid",rc={"axes.facecolor":"#CAF1DE"})

# %%
# Displaying data in the UceResultsDataSet file
df =pd.read_csv('UceResultsDataSet.csv')
df
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
# Displaying the column headings in the data set
df.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
#check if there are null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# FEMALE TOTAL DIV7     12875
# TOTAL DIV 7           11150
# MALE TOTAL DIV7       10131
# FEMALE TOTAL DIV1      9114
# MALE TOTAL DIV1        7601
# MALE TOTAL X           7260
# MALE TOTAL DIV9        7120
# FEMALE TOTAL X         7043
# FEMALE TOTAL DIV9      5290
# TOTAL DIV 1            4781
# TOTAL X                4235
# TOTAL DIV 9            4185
# FEMALE TOTAL DIV2      3307
# MALE TOTAL DIV2        2397
# MALE TOTAL DIV4        1379
# MALE TOTAL DIV3        1240
# FEMALE TOTAL DIV3      1165
# FEMALE TOTAL DIV4       958
# TOTAL DIV 2             759
# TOTAL DIV 4             751
# TOTAL DIV 3             471
# TOTAL CANDIDATES        271
# MALE % DIV4             134
# MALE % DIV3             134
# MALE % DIV7             134
# MALE % DIV2             134
# MALE % DIV1             134
# MALE % DIV9             134
# MALE % X                134
# FEMALE % X               58
# FEMALE % DIV3            58
# FEMALE % DIV9            58
# FEMALE % DIV4            58
# ...

# %%
import pandas as pd
#Replacing all null values with zero
df = pd.read_csv('UceResultsDataSet.csv')

df.fillna(value=0, inplace=True)

# %%
#Checking again if there are still any null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# YEAR                  0
# DISTRICT              0
# FEMALE % DIV4         0
# FEMALE TOTAL DIV7     0
# FEMALE % DIV7         0
# FEMALE TOTAL DIV9     0
# FEMALE % DIV9         0
# FEMALE TOTAL X        0
# FEMALE % X            0
# MALE CANDIDATES       0
# MALE TOTAL DIV1       0
# MALE % DIV1           0
# MALE TOTAL DIV2       0
# MALE % DIV2           0
# MALE TOTAL DIV3       0
# MALE % DIV3           0
# MALE TOTAL DIV4       0
# MALE % DIV4           0
# MALE TOTAL DIV7       0
# MALE % DIV7           0
# MALE TOTAL DIV9       0
# MALE % DIV9           0
# MALE TOTAL X          0
# FEMALE TOTAL DIV4     0
# FEMALE % DIV3         0
# FEMALE TOTAL DIV3     0
# % DIV 4               0
# SCHOOL                0
# TOTAL CANDIDATES      0
# TOTAL DIV 1           0
# % DIV 1               0
# TOTAL DIV 2           0
# % DIV 2               0
# TOTAL DIV 3           0
# % DIV 3               0
# TOTAL DIV 4           0
# TOTAL DIV 7           0
# FEMALE % DIV2         0
# ...

# %%
#Checking if they are any duplicated values
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17634    False
# 17635    False
# 17636    False
# 17637    False
# 17638    False
# Length: 17639, dtype: bool

# %%
# Removing the duplicates from the data set
df.drop_duplicates(inplace=True)

# %%
# converting the column values to float so that they are uniform and consistent 
columns_to_convert = ['% DIV 1',  '% DIV 2', '% DIV 3',
        '% DIV 4', '% DIV 7', 
       '% DIV 9', '% X', 
       'FEMALE % DIV1 ',  'FEMALE % DIV2',
        'FEMALE % DIV3', 
       'FEMALE % DIV4','FEMALE % DIV7',
        'FEMALE % DIV9','FEMALE % X ',
        'MALE % DIV1 ',
        'MALE % DIV2', 'MALE % DIV3',
        'MALE % DIV4 ',  'MALE % DIV7',
        'MALE % DIV9', 'MALE % X']  

df[columns_to_convert] = df[columns_to_convert].astype(float)

# %%
df['TOTAL CANDIDATES'].plot(kind= 'line')
# Out:
# <Axes: >

# %%
#A histogram representing the number of TOTAL CANDIDATES
import matplotlib.pyplot as plt
df['TOTAL CANDIDATES'].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['TOTAL DIV 1'].plot(kind= 'line')
# Out:
# <Axes: >

# %%
#A histogram representing the number of % DIV 1
df['% DIV 1'].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['% DIV 1'].plot(kind= 'line')
# Out:
# <Axes: >

# %%
# DATA ANALYSIS AND VISUALISATION ON THE CRIME DATA SET 2018

# %%
# Displaying the data set 
df2 = pd.read_csv('crimeDataSet.csv')
df2
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
#displayong the number of rows and columns we have in the data set
df2.shape
# Out:
# (127, 38)

# %%
#Displaying the column names we have in the data set
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
# AS shown above we have alot of unmaned columns 
# Renaming them
import pandas as pd

# Assuming your dataset is stored in a DataFrame called 'df'
df2.rename(columns={'Unnamed: 0': 'Column1', 'Unnamed: 1': 'Column2','REPORTED CASES':'REPORTED CASES-Totals Cases', 'Unnamed: 3': 'REPORTED CASES-Cases under Inquiry', 'Unnamed: 4': 'REPORTED CASES-Not Detected/NPW',
                    'Unnamed: 5': 'REPORTED CASES-Cases taken to court', 'PERFOMANCE':'PERFOMANCE-Cases submitted toDPP/RSA' ,'Unnamed: 7': 'PERFOMANCE-Cases with convictions',
                      'Unnamed: 8': 'PERFOMANCE-Cases with Acquittals', 'Unnamed: 9': 'PERFOMANCE-Cases Dismissed',
                     'Unnamed: 10': 'PERFOMANCE-Cases pending in Court','PERSONS TAKEN TO COURT':'PERSONS TAKEN TO COURT-Male Adult', 'Unnamed: 12': 'PERSONS TAKEN TO COURT-Male Juven.', 'Unnamed: 13': 'PERSONS TAKEN TO COURT-Female Adult',
                      'Unnamed: 14': 'PERSONS TAKEN TO COURT-Female Juven.', 'Unnamed: 15': 'ACCUSED CONVICTED-Male Adult', 'Unnamed: 16': 'ACCUSED CONVICTED-Male Juven.',
                       'Unnamed: 17': 'ACCUSED CONVICTED-Female Adult', 'Unnamed: 18': 'ACCUSED CONVICTED-Female Juven.', 'Unnamed: 19': 'ACCUSED CONVICTED-Acquitted',
                        'Unnamed: 20': 'ACCUSED CONVICTED-Discharged', 'Unnamed: 21': 'ACCUSED CONVICTED-Awaiting', 'SENTENCES IMPOSED BY COURTS':'SENTENCES IMPOSED BY COURTS-Trial', 'Unnamed: 23': 'SENTENCES IMPOSED BY COURTS-Male Juven.',
                         'Unnamed: 24': 'SENTENCES IMPOSED BY COURTS-Female Adult', 'Unnamed: 25': 'SENTENCES IMPOSED BY COURTS-Female Juven.', 'Unnamed: 26': 'SENTENCES IMPOSED BY COURTS-Death',
                          'Unnamed: 27': 'SENTENCES IMPOSED BY COURTS-Fined', 'Unnamed: 28': 'SENTENCES IMPOSED BY COURTS-Probation', 'Unnamed: 29': 'SENTENCES IMPOSED BY COURTS-Bound Over',
                           'Unnamed: 30': 'SENTENCES IMPOSED BY COURTS-COMM. WORK', 'Unnamed: 31': 'SENTENCES IMPOSED BY COURTS-Fines  Awarded (UgShs.)', 'Unnamed: 32': 'VICTIMS OF CRIME-Male Adult',
                            'Unnamed: 33': 'VICTIMS OF CRIME-Male Juven.', 'Unnamed: 34': 'VICTIMS OF CRIME-Female Adult', 'Unnamed: 35': 'VICTIMS OF CRIME-Female Juven.',
                             'Unnamed: 36': 'VALUE PROPERTY(UGSHS.)-Lost', 'Unnamed: 37': 'VALUE PROPERTY(UGSHS.)-Recovered'}, inplace=True)
df2
# Out:
#     Column1                Column2 REPORTED CASES-Totals Cases  \
# 0       NaN                    NaN                         NaN
# 1       NaN                    NaN                Totals Cases
# 2     S/No.  CASE/CRIME INCIDENCES                           1
# 3       NaN              HOMICIDES                         NaN
# 4         1   Death  (by shooting)                         190
# ..      ...                    ...                         ...
# 122      98            UWA Statute                         648
# 123      99   Local Government Act                           4
# 124     100         All other Acts                         821
# 125     NaN  Sub Total(Other Laws)                       3,006
# 126     NaN            GRAND TOTAL                     238,746
#
#     REPORTED CASES-Cases under Inquiry REPORTED CASES-Not Detected/NPW  \
# 0                                  NaN                             NaN
# ...

# %%
#Removing rows with null values
df2 =df2.dropna()
df2
# Out:
#     Column1                               Column2 REPORTED CASES-Totals Cases  \
# 4         1                  Death  (by shooting)                         190
# 5         2                 Death (by mob action)                         636
# 6         3                     Death (Poisoning)                          81
# 7         4  Death (Aggravated Domestic Violence)                         362
# 8         5                Death(Fire Out Breaks)                          42
# ..      ...                                   ...                         ...
# 120      96                          Firearms Act                         109
# 121      97                            Enguli Act                           4
# 122      98                           UWA Statute                         648
# 123      99                  Local Government Act                           4
# 124     100                        All other Acts                         821
#
# ...

# %%
# displaying the new number of columns and rows we have after deleting the empty ones
df2.shape
# Out:
# (83, 38)

# %%
#Checking if there are still null values
df2.isnull().sum().sort_values(ascending=False)
# Out:
# Column1                                                0
# SENTENCES IMPOSED BY COURTS-Probation                  0
# ACCUSED CONVICTED-Awaiting                             0
# SENTENCES IMPOSED BY COURTS-Trial                      0
# SENTENCES IMPOSED BY COURTS-Male Juven.                0
# SENTENCES IMPOSED BY COURTS-Female Adult               0
# SENTENCES IMPOSED BY COURTS-Female Juven.              0
# SENTENCES IMPOSED BY COURTS-Death                      0
# SENTENCES IMPOSED BY COURTS-Fined                      0
# SENTENCES IMPOSED BY COURTS-Bound Over                 0
# Column2                                                0
# SENTENCES IMPOSED BY COURTS-COMM. WORK                 0
# SENTENCES IMPOSED BY COURTS-Fines  Awarded (UgShs.)    0
# VICTIMS OF CRIME-Male Adult                            0
# VICTIMS OF CRIME-Male Juven.                           0
# VICTIMS OF CRIME-Female Adult                          0
# ...

# %%
#Checking if there are any duplicates 
print(df2.duplicated())
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# Length: 83, dtype: bool

# %%
# Remove rows with non-numeric values in a specific column
df2 = df2[pd.to_numeric(df2['REPORTED CASES-Totals Cases'], errors='coerce').notnull()]

df2 = df2[pd.to_numeric(df2['REPORTED CASES-Cases under Inquiry'], errors='coerce').notnull()]

# %%
# Converting the specified colum values to float for easy manupulation
columns_to_convert = ['REPORTED CASES-Totals Cases','REPORTED CASES-Cases under Inquiry']  

df2[columns_to_convert] = df2[columns_to_convert].astype(float)

# %%
#Histogram for REPORTED CASES-Totals Cases
import matplotlib.pyplot as plt
df2['REPORTED CASES-Totals Cases'].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#A line graph for REPORTED CASES-Totals Cases
df2['REPORTED CASES-Totals Cases'].plot(kind= 'line')
# Out:
# <Axes: >

# %%
# Histogram for REPORTED CASES-Cases under Inquiry
import matplotlib.pyplot as plt
df2['REPORTED CASES-Cases under Inquiry'].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Line graph for REPORTED CASES-Cases under Inquiry
df2['REPORTED CASES-Cases under Inquiry'].plot(kind= 'line')
# Out:
# <Axes: >
